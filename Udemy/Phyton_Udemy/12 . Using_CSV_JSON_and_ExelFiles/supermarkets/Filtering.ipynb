# %%
import os
import pandas
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Filtering.ipynb',
#  'Loading.ipynb',
#  'Setting.ipynb',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
df1 = pandas.read_csv('supermarkets-commas.txt')
df2 = pandas.read_csv('supermarkets-semi-colons.txt')
df3 = pandas.read_csv('supermarkets.csv')
df4 = pandas.read_json('supermarkets.json')
df5 = pandas.read_excel('supermarkets.xlsx')

# %%
df7exp = df3.set_index("Address")
df7exp
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
#archive.loc[Fila,Columna]#]
#df7exp.loc["FilaRango1":"FilaRango2","ColumnaRango1": "ColumnaRango2"]#
df7exp.loc["735 Dolores St":"332 Hill St","ID": "State"] #Busqueda por Rangos#
# Out:
#                 ID           City             State
# Address
# 735 Dolores St   2  San Francisco          CA 94119
# 332 Hill St      3  San Francisco  California 94114

# %%
#Interseccion entre Fila y Columna
df7exp.loc["332 Hill St", "State"]
# Out:
# 'California 94114'

# %%
#Listo los elemento de una Columna
list(df7.loc[:,"Name"])
# Out:
# ['Madeira',
#  'Bready Shop',
#  'Super River',
#  "Ben's Shop",
#  'Sanchez',
#  'Richvalley']

# %%
#Listar los elemtos de un Indice
list(df7.loc["332 Hill St",])
# Out:
# [np.int64(3),
#  'San Francisco',
#  'California 94114',
#  'USA',
#  'Super River',
#  np.int64(25)]

# %%
df7
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
#Buscar por posiciones los elementos de una tabla#
df1.iloc[0:4, 1:4]
# Out:
#           Address           City             State
# 0    3666 21st St  San Francisco          CA 94114
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114
# 3    3995 23rd St  San Francisco          CA 94114
